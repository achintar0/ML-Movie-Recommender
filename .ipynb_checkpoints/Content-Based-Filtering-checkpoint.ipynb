# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ratings_path = "ml-latest-small-100K/ratings.csv"
movies_path = "ml-latest-small-100K/movies.csv"
links_path = "ml-latest-small-100K/links.csv"

# %%
ratings_data = pd.read_csv(ratings_path)
movies_data = pd.read_csv(movies_path)
links_data = pd.read_csv(links_path)

# %%
ratings_data.head(20)
# Out:
#     userId  movieId  rating  timestamp
# 0        1        1     4.0  964982703
# 1        1        3     4.0  964981247
# 2        1        6     4.0  964982224
# 3        1       47     5.0  964983815
# 4        1       50     5.0  964982931
# 5        1       70     3.0  964982400
# 6        1      101     5.0  964980868
# 7        1      110     4.0  964982176
# 8        1      151     5.0  964984041
# 9        1      157     5.0  964984100
# 10       1      163     5.0  964983650
# 11       1      216     5.0  964981208
# 12       1      223     3.0  964980985
# 13       1      231     5.0  964981179
# 14       1      235     4.0  964980908
# 15       1      260     5.0  964981680
# 16       1      296     3.0  964982967
# 17       1      316     3.0  964982310
# 18       1      333     5.0  964981179
# 19       1      349     4.0  964982563

# %%
movies_data.head(20)
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# ...

# %%
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# Creating movie title wordcloud
movies_data['title'] = movies_data['title'].fillna("").astype('str')
title_corpus = ' '.join(movies_data['title'])
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='black', height=2000, width=4000).generate(title_corpus)

# Wordcloud plot
plt.figure(figsize=(16,5))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %%
# get statistics of ratings
ratings_data['rating'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')
sns.set(font_scale=1.5)

# display rating distr
sns.distplot(ratings_data['rating'].fillna(ratings_data['rating'].median()))
# Out:
# /tmp/ipykernel_51584/464832962.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ratings_data['rating'].fillna(ratings_data['rating'].median()))
# /home/achintar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='rating', ylabel='Density'>

# %%
#join files into a single dataframe
dataset = pd.merge(pd.merge(movies_data, ratings_data), links_data)

dataset[['userId', 'movieId', 'tmdbId', 'title', 'genres', 'rating']].sort_values('rating', ascending=False).head(20)
# Out:
#        userId  movieId   tmdbId                              title  \
# 56251     567     3676    985.0                  Eraserhead (1977)
# 33888     147     1639   2255.0                 Chasing Amy (1997)
# 20742     188      914  11113.0                My Fair Lady (1964)
# 10168     283      356     13.0                Forrest Gump (1994)
# 10169     284      356     13.0                Forrest Gump (1994)
# 65379     391     5013   5279.0                Gosford Park (2001)
# 10171     288      356     13.0                Forrest Gump (1994)
# 20739     169      914  11113.0                My Fair Lady (1964)
# 10173     294      356     13.0                Forrest Gump (1994)
# 10174     296      356     13.0                Forrest Gump (1994)
# 65385     517     5013   5279.0                Gosford Park (2001)
# 45324     453     2572   4951.0  10 Things I Hate About You (1999)
# 10178     304      356     13.0                Forrest Gump (1994)
# ...
